# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy
import seaborn

# %%
df=pd.read_csv('../data/freight_inventory.csv')

# %%
df
# Out:
#      Shipment_ID     Origin Destination  Distance_km Shipment_Mode    Carrier  \
# 0         SH1000  Ahmedabad     Chennai         1330          Road        SCI
# 1         SH1001      Kochi     Chennai          585          Road        TCI
# 2         SH1002      Kochi     Chennai          389          Road     CONCOR
# 3         SH1003  Bengaluru      Mumbai         2190          Rail        TCI
# 4         SH1004    Kolkata      Mumbai        14805         Ocean       Gati
# ...          ...        ...         ...          ...           ...        ...
# 1195      SH2195      Kochi     Chennai         1270          Road  Blue Dart
# 1196      SH2196  Ahmedabad   Bengaluru          231          Road        SCI
# 1197      SH2197      Kochi       Delhi          400          Road  Blue Dart
# 1198      SH2198    Kolkata   Bengaluru          494          Road        TCI
# 1199      SH2199      Kochi   Ahmedabad        12075         Ocean  Blue Dart
#
# ...

# %%
for i in df.columns:
    print(i)
# Out:
# Shipment_ID
# Origin
# Destination
# Distance_km
# Shipment_Mode
# Carrier
# Quantity
# Weight_kg
# Volume_m3
# Shipment_Value_INR
# Weather_Conditions
# Traffic_Conditions
# Planned_Duration_Days
# Actual_Duration_Days
# Delay_Days
# Status

# %%
df.groupby('Origin')['Quantity'].sum()
# Out:
# Origin
# Ahmedabad    749278
# Bengaluru    696622
# Chennai      683930
# Delhi        783805
# Hyderabad    708557
# Kochi        856009
# Kolkata      798879
# Mumbai       749489
# Name: Quantity, dtype: int64

# %%
df.groupby('Origin')['Status'].count()
# Out:
# Origin
# Ahmedabad    150
# Bengaluru    135
# Chennai      123
# Delhi        153
# Hyderabad    150
# Kochi        174
# Kolkata      156
# Mumbai       159
# Name: Status, dtype: int64

# %%
df.groupby('Origin')['Status'].value_counts()
# Out:
# Origin     Status
# Ahmedabad  Delayed    78
#            On Time    72
# Bengaluru  Delayed    71
#            On Time    64
# Chennai    Delayed    66
#            On Time    57
# Delhi      Delayed    88
#            On Time    65
# Hyderabad  Delayed    82
#            On Time    68
# Kochi      Delayed    98
#            On Time    76
# Kolkata    Delayed    79
#            On Time    77
# Mumbai     Delayed    80
#            On Time    79
# Name: count, dtype: int64
